# %%
import random

def playRiddlePuzzle():
    riddles = {'What has to be broken before you can use it?' : "egg", 
              "I’m tall when I’m young, and I’m short when I’m old. What am I?":"candle",
             "What is full of holes but still holds water?":"sponge",
             "What is always in front of you but can’t be seen?":"future",
             "What gets wet while drying?":"towel","I have branches, but no fruit, trunk or leaves. What am I?":"bank",
             "The more of this there is, the less you see. What is it?":"darkness",
             "What gets bigger when more is taken away?":"hole"}

    total_riddles = len(riddles)                         #total length of the dictionary
    score = 0

    choices = list(riddles.keys())                                 
   
    play_again = 'yes'

    for i in riddles:  
        random_riddle = random.choice(choices)
        y = riddles[random_riddle]

        print("\nRiddle:", random_riddle)
        x = input("Your answer: ").lower()

        if x== y.lower():
            print("Correct!")
            score =score+1
        else:
            print("Oops ! Incorrect! The correct answer is: ",y)

    score_percentage = (score / total_riddles) * 100
    print("Your final score:" ,score_percentage,"%")

    play_again = input("Do you want to play again? (yes/no): ").lower()
    if play_again == 'yes':
        playRiddlePuzzle()
    else:
        print('\nTHANK YOU FOR PLAYING')
playRiddlePuzzle()
# Out:
# Riddle: I’m tall when I’m young, and I’m short when I’m old. What am I?
# Your answer: spfs
# Oops ! Incorrect! The correct answer is:  candle
#
# Riddle: What is always in front of you but can’t be seen?
# Your answer: fs
# Oops ! Incorrect! The correct answer is:  future
#
# Riddle: What has to be broken before you can use it?
# Your answer: sfs
# Oops ! Incorrect! The correct answer is:  egg
#
# Riddle: What has to be broken before you can use it?
# Your answer: fsf
# Oops ! Incorrect! The correct answer is:  egg
#
# Riddle: What gets wet while drying?
# Your answer: sfs
# Oops ! Incorrect! The correct answer is:  towel
#
# Riddle: What is full of holes but still holds water?
# Your answer: fs
# Oops ! Incorrect! The correct answer is:  sponge
#
# Riddle: What is always in front of you but can’t be seen?
# Your answer: sf
# Oops ! Incorrect! The correct answer is:  future
#
# Riddle: The more of this there is, the less you see. What is it?
# Your answer: darkness
# Correct!
# ...

# %%
import random

def calculate_answer(num1, operator, num2):
    if operator == '+':
        return num1 + num2
    elif operator == '-':
        return num1 - num2
    elif operator == '*':
        return num1 * num2
    elif operator == '/':
        return num1 // num2                                 # Using floor division for simplicity

def play_arithmetic_game():
    print("Welcome to the Arithmetic Logic Puzzle game")
    print("Rules are straightforward:")
    print("* Solve the arithmetic puzzles to score points.")
    print("* You will be given two numbers and an operator.")
    print("* Enter your answer to the arithmetic problem.")
    print("* If your answer is correct, you score a point.")
    print("* The game continues with a total of 5 problems.")
    print("Get ready to play")

    score = 0
    total_problems = 5
    play_again = 'yes'

    for _ in range(total_problems):
        num1 = random.randint(1, 21)            #randint() is used to generate a random integer between 1 and 20   
        num2 = random.randint(1, 21)
        operator = random.choice(['+', '-', '*', '/'])

        print("solve:",num1, operator, num2)
        user_answer = float(input("Your answer: "))

        correct_answer = calculate_answer(num1, operator, num2)

        if user_answer == correct_answer:
            print("Correct! You scored a point!")
            score += 1
        else:
            print(f"Oops! The correct answer is {correct_answer}. Keep trying!")

    percentage_score = (score / total_problems) * 100
    print("\nGreat job! Your final score is: ",percentage_score,"%")
    
    play_again = input("Do you want to play again? (yes/no): ").lower()
    
    if play_again == 'yes':
        play_arithmetic_game()
    else:
        print("\nTHANK YOU FOR PLAYING")


play_arithmetic_game()
# Out:
# Welcome to the Arithmetic Logic Puzzle game
# Rules are straightforward:
# * Solve the arithmetic puzzles to score points.
# * You will be given two numbers and an operator.
# * Enter your answer to the arithmetic problem.
# * If your answer is correct, you score a point.
# * The game continues with a total of 5 problems.
# Get ready to play
# solve: 4 - 19
# Your answer: 23
# Oops! The correct answer is -15. Keep trying!
# solve: 2 - 19
# Your answer: 12
# Oops! The correct answer is -17. Keep trying!
# solve: 13 * 1
# Your answer: 32
# Oops! The correct answer is 13. Keep trying!
# solve: 15 / 12
# Your answer: 32
# Oops! The correct answer is 1. Keep trying!
# solve: 16 + 18
# Your answer: 32
# Oops! The correct answer is 34. Keep trying!
#
# Great job! Your final score is:  0.0 %
# Do you want to play again? (yes/no): yes
# Welcome to the Arithmetic Logic Puzzle game
# Rules are straightforward:
# * Solve the arithmetic puzzles to score points.
# ...

# %%
import random 
def playRPSWithComputer():
    print("Welcome to the Rock-Paper-Scissors game")
    print("Rules are straightforward")
    print("*Players can enter one choice at a time, else invalid choice")
    print("*Rock smashes scissors")
    print("*Paper covers rock")
    print("*Scissors cut paper")
    print("*If both player's choice is same, Then it is draw")
    print("You are Player 2 and Computer is PLayer 1")
    print(" ")
    print("Get ready to play")
    print("")
    user=input('enter your choice(player2):')
    c=['rock','paper','scissors']                                          #list of choices
    comp=random.choice(c)                                                  #the random choices willl stored in comp variable
    if comp=='rock' and user=='paper':
        print('Your choice',user)
        print('Player 1 choice was',comp)
        print("paper covers rock.Player 2 won Yayyyy!!!! CONGRATS")
    elif comp=='paper' and user=='scissors':
        print('Your choice',user)
        print('Player 1 choice was',comp)
        print("Scissors cut Paper.Player 2 won Yayyyy!!!! CONGRATS")
    elif comp=='scissors' and user=='rock':
        print('Your choice',user)
        print('Player 1 choice was',comp)
        print("rock smashes scissors.Player 2 won Yayyyy!!!! CONGRATS")
    elif comp=='rock' and user=='scissors':
        print("your choice",user)
        print("player 2 choice was:",comp)
        print("rock smashes scissors.Player 1 won.Better luck next time")
    elif comp=='scissors' and user=='paper':
        print('Your choice',user)
        print('Player 1 choice was',comp)
        print("Scissors cut Paper.Player 1 won.Better luck next time")
    elif comp=='paper' and user=='rock':
        print('Your choice',user)
        print('Player 1 choice was',comp)
        print("paper covers rock.Player 1 won.Better luck next time")
    elif comp==user:
        print('Your choice',user)
        print('Player 1 choice was',comp)
        print(" ")
        print("DRAW!!!. Same choice.Play again")
    else:
        print("Invalid choice.Please enter rock, paper, scissors only, Please read the rules again.")

print(" ")    

print('THANK YOU FOR PLAYING')
playRPSWithComputer()
# Out:
#
# THANK YOU FOR PLAYING
# Welcome to the Rock-Paper-Scissors game
# Rules are straightforward
# *Players can enter one choice at a time, else invalid choice
# *Rock smashes scissors
# *Paper covers rock
# *Scissors cut paper
# *If both player's choice is same, Then it is draw
# You are Player 2 and Computer is PLayer 1
#
# Get ready to play
#
# enter your choice(player2):rock
# Your choice rock
# Player 1 choice was paper
# paper covers rock.Player 1 won.Better luck next time

# %%
def playRPSwithuser():
    print("Welcome to the Rock-Paper-Scissors game")
    print("Rules are straightforward")
    print("* Players can enter one choice at a time, else invalid choice")
    print("* Rock smashes scissors")
    print("* Paper covers rock")
    print("* Scissors cut paper")
    print("* If both player's choices are the same, Then it is a draw")
    print(" ")
    print("Get ready to play")
    print("")

    user1 = input("Enter Player 1's choice (rock/paper/scissors): ")
    user2 = input("Enter Player 2's choice (rock/paper/scissors): ")

    choices = ['rock', 'paper', 'scissors']

    if user1 in choices and user2 in choices:
        print("\nPlayer 1's choice:", user1)
        print("Player 2's choice:", user2)
        
        if user1=='rock' and user2=='paper':
            print('player1 chocie ',user1)
            print('Player 2 choice was',user2)
            print("paper covers rock.     \nPlayer 2 won Yayyyy!!!! CONGRATS")
            
        elif user1=='paper' and user2=='scissors':
            print('Your choice',user1)
            print('Player 1 choice was',user2)
            print("Scissors cut Paper. \nPlayer 2 won Yayyyy!!!! CONGRATS")
        
        elif user1=='scissors' and user2=='rock':
            print('Player1 choice:',user1)
            print('Player2 choice:',user2)
            print("rock smashes scissors.\n Player 2 won Yayyyy!!!! CONGRATS")
        
        elif user1=='rock' and user2=='scissors':
            print("Player1 choice:",user1)
            print("player 2 choice :",user2)
            print("rock smashes scissors. \n Player 1 won.Better luck next time")
        
        elif user1=='scissors' and user2=='paper':
            print('Your choice',user1)
            print('Player 1 choice was',user2)
            print("Scissors cut Paper. \n Player 1 won.Better luck next time")
        
        elif user1=='paper' and user2=='rock':
            print('Your choice',user1)
            print('Player 1 choice was',user2)
            print("paper covers rock. \n Player 1 won.Better luck next time")
        
        elif user1==user2:
            print('Your choice',user1)
            print('Player 1 choice was',user2)
            print(" ")
            print("DRAW!!!. Same choice.Play again")
        else:
            print("Invalid choice.Please enter rock, paper, scissors only, Please read the rules again.")
playRPSwithuser()
# Out:
# Welcome to the Rock-Paper-Scissors game
# Rules are straightforward
# * Players can enter one choice at a time, else invalid choice
# * Rock smashes scissors
# * Paper covers rock
# * Scissors cut paper
# * If both player's choices are the same, Then it is a draw
#
# Get ready to play
#
# Enter Player 1's choice (rock/paper/scissors): scissors
# Enter Player 2's choice (rock/paper/scissors): paper
#
# Player 1's choice: scissors
# Player 2's choice: paper
# Your choice scissors
# Player 1 choice was paper
# Scissors cut Paper.
#  Player 1 won.Better luck next time

# %%
import random

def wordguessinggame():
    words = ["elephant", "mountain", "ocean", "butterfly", "adventure", "sunshine"]
    secret_word = random.choice(words)
    attempts = 5

    print("Welcome to the Word Guessing Game!")
    print("Guess the secret word.")

    while attempts > 0:
        guess = input("Enter your guess: ").lower()

        if guess == secret_word:
            print("Congratulations! You guessed the correct word:", secret_word)
            break
        else:
            attempts -= 1
            print("Wrong guess!   attempts :",attempts)

    if attempts == 0:
        print("Sorry! You ran out of attempts. The correct word was:", secret_word)
wordguessinggame()

# %%
def quit_program():
    print("Thank you for playing. Goodbye!")

# %%
def menu():
    for _ in range(1):  # This loop will run only once
        print("Application Menu:")
        print("1. Play Riddle Puzzle")
        print("2. Play Arithmetic Puzzle")
        print("3. Play Rock-Paper-Scissors with Computer")
        print("4. Play Rock-Paper-Scissors between Users")
        print("5. Play Word Guessing Game")
        print("6. Quit")

        user_choice = input("Enter your choice (1-6): ")

        if user_choice == '1':
            playRiddlePuzzle()
        elif user_choice == '2':
            
            playArithmeticPuzzle()
        elif user_choice == '3':
            playRockPaperScissorsComputer()
        elif user_choice == '4':
            playRockPaperScissorsUser()
        elif user_choice == '5':
            playWordGuessingGame()
        elif user_choice == '6':
            quit_program()
        else:
            print("You have entered the wrong option. Please enter a number between 1 and 6.")

        play_again = input("Do you want to play another game? (Y/y for Yes, N/n for No): ")
        if play_again.lower() == 'y':
            menu()
        else:
            print("Thanks for playing")

menu()
